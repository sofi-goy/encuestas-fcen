# %%
import glob
import cv2
import matplotlib.pyplot as plt
import pytesseract
from queue import Queue

def bucket_invert(img, start_x, start_y):
    candidatos = Queue()
    candidatos.put((start_x, start_y))
    while not candidatos.empty():
        x, y = candidatos.get()
        if x < 0 or y < 0 or x >= img.shape[0] or y >= img.shape[1]:
            continue

        if img[x, y] == 0:
            img[x, y] = 255
            candidatos.put((x+1, y))
            candidatos.put((x-1, y))
            candidatos.put((x, y+1))
            candidatos.put((x, y-1))
        
    return img

for file in glob.glob("respuestas/*.png"):
    print(file)
    img = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
    # invert image
    img = cv2.bitwise_not(img)
    
    img = bucket_invert(img, 0, 0)
    img = bucket_invert(img, img.shape[0]-1, 0)
    img = bucket_invert(img, 0, img.shape[1]-1)
    img = bucket_invert(img, img.shape[0]-1, img.shape[1]-1)

    plt.imshow(img, cmap="gray")
    plt.show()

    # scale to 300 dpi
    img = cv2.resize(img, None, fx=10, fy=10, interpolation=cv2.INTER_CUBIC)

    # pass to ocr
    text = pytesseract.image_to_string(img, config="--psm 6 -c tessedit_char_whitelist=\"0123456789.\"")
    print(text)
# Out:
# respuestas/973b49003ae709d605f7388f29ba5157.png
# 3.7
#
# respuestas/595da3ee58c8eb4d067dd170c1f2b2c7.png
# respuestas/8d0b136a38688e47a8aa43472570a40b.png
# 7
#
# respuestas/4bb113796c5d163779216aff7bce8ec0.png
# 3.4
#
# respuestas/17b2854f51f98df73b5dc31e66bde615.png
# respuestas/7a427026f1022c3c783f5fe43696be78.png
# 3.5
#
# respuestas/724bd4b0ae71cfb44d4d83e4a4d98fc9.png
# 3.7
#
# respuestas/7a49053c0e74873e3ab4a1cdb54de66e.png
# 4.4
# .
#
# respuestas/8e841359a977a8460832faac25a2a1d1.png
# .
#
# respuestas/5a1a8956ca467641a14e7dce7d8f2f37.png
# 4.4
#
# respuestas/3dfce0663ce0174a9ea97d1c05d09744.png
# 4.5
#
# respuestas/5321dca375a52a09a40104bd7f8309f7.png
# ..
# .
#
# respuestas/cdc6977023ab5dc277cfa1d55b5e426d.png
# 4.5
#
# respuestas/393bfe63682621d997818d3149bf0f44.png
# 4
#
# respuestas/19a47118574f89ecebea8af67a37cbf0.png
# 3.9
#
# respuestas/899bb9d854d12e16945c3a5a742e2777.png
# 19
#
# respuestas/047510e6c63a6be25fa7fd89aab134e3.png
# 3.7
# 4
#
# respuestas/2a56573b789eafa88ce3d1f2e3091a19.png
# 3.6
#
# respuestas/e14abfb43e4ef46cd08add45af0bc800.png
# 33
#
# respuestas/d52ca6364967bffdb601b6eaf51d1641.png
# 4.0
#
# respuestas/204c41e9705092c590d34629c1444f40.png
# 1
# 4
#
# respuestas/1320151a4f433c5d88cd11ef9df320fe.png
# 4.4
#
# respuestas/d19704e2ac69672865c6fca63b8b21d7.png
# 4.3
#
# respuestas/1835b2c869146217890063bd6a9fcea7.png
# 4.4
#
# respuestas/9146f6db868d673d52909e209f128ee7.png
# respuestas/c57c47500ab11c9c12b26663568ad99c.png
# .
# 8
#
# respuestas/ddfc3117e9b898f7f5127434b654b6d6.png
# 3.6
#
# respuestas/060cea1593af1d91cd6265051a35e568.png
# 33.
#
# respuestas/bab5161c928f160daf9708f20f97d28c.png
# 3.3
#
# respuestas/b9629502d199f184326be4a2fd788282.png
# 3.8
#
# respuestas/5fa5a74e2fe831dca24db640c59cdfc0.png
# respuestas/6a13124248e5e30e9f8357f98c44678e.png
# respuestas/be661b45be902cbf9d50091b6dca3314.png
# 4.4
#
# respuestas/0531f25e79a0f4df0bfe4db8d27e8d72.png
# 3.9
#
# respuestas/22973da1d5b234720a4ade579b68a50d.png
# 4.5
#
# respuestas/ddaff8f171c75c1261e03407653ef224.png
# 3.9
#
# respuestas/253d613b22a229d1b320d3078cb774f7.png
# 3.9
#
# respuestas/f45bb0e566d2ed2a71ba3b70da22c2b1.png
# 3.8
#
# respuestas/4bdaf020c7d9336bd9ae34871398e9af.png
# 3.5
# .
#
# respuestas/52e3ed238e60517f70ecabb1b60165b3.png
# 3.8
#
# respuestas/012f281d7fe9ed921fd9832b2d8197f7.png
# 39.
#
# respuestas/6edcceffa430cc994d61b147014a0a7f.png
# 721
# 4
#
# respuestas/f9f041d54d6ea3f584f57825303604e6.png
# 4.3
#
# respuestas/d0cb4ea8bb26c95cc7c5baa70afaaa2d.png
# 3.
#
# respuestas/415697a6c97245138a8f54cffc0b6218.png
# 43
#
# respuestas/cd0a51175982cb98a112d742266530a8.png
# 3.5
#
# respuestas/0519a436252bf83ee1b441cb6a974a48.png
# 4
# 3.2
#
# respuestas/d0779787e339b9faa0ee2e6cf47b34b3.png
# 3.9
#
# respuestas/c13975f775def29fc89055e2e2a4dd1e.png
# 3.7
#
# respuestas/dd30121d1c229c78bc6fdd31e5bec205.png
# 3.9.
#
# respuestas/2d5ba0fb722b085521aacd77d287d133.png
# 4.3
#
# respuestas/50f75db528231b34fb0e6616a68391bf.png
# 3.7
#
# respuestas/fcb8a729a91e6d057ba428bfa8f39f42.png
# 19
#
# respuestas/80af137511460672b87903f919aab9c8.png
# 3.9
#
# respuestas/588e0dc2768b067c152ada28bc3c50e4.png
# 3.3
#
# respuestas/a535391d20ef871b71b80191aa425c4c.png
# 3.7
#
# respuestas/4fa34e72e4c6e5e440043debc7308d7a.png
# 4.2
#
# respuestas/c707f72868eec513ea5c33a7b496e13c.png
# respuestas/cc95db9c6644cc61627d5d1c6cf5e0ff.png
# 3.9
#
# respuestas/144fad99d57a456536965a398a1343ca.png
# 4.2
#
# respuestas/bbebb1e4a7e7a821448b9332209f966d.png
# 3.3
#
# respuestas/d3608e9b0610e28971e57f71aa73ae3f.png
# 3.5
#
# respuestas/8d311b5abccd3592bb6781e497369269.png
# 2
#
# respuestas/e65dc761719e913cb4359c4c106ddfc5.png
# 13.
# 4
#
# respuestas/49dc0cb38aaf294199b5550ecd18d9f9.png
# 3.2
#
# respuestas/2c3c5ac4657ac67721c8f7efca800feb.png
# respuestas/d524c11ae5d11559f9b9d27de9ed92d1.png
# 4.3
#
# respuestas/626cb4d0d92a5c60b4e5a47a4b50a987.png
# 3.6
#
# respuestas/ded4dd0e09910342c496a7ab5f625a54.png
# 3.6
#
# respuestas/34ee59319de0693bf6720629b05760ef.png
# 3.1
#
# respuestas/52928f1c6195820c98004d85aeca064e.png
# 4.9
#
# respuestas/c515df9b0005c53cdd9e4fdbd3f9a399.png
# respuestas/88e0b5312f8b1e2ceec5a34495250a84.png
# 3.8
#
# respuestas/bc26c652db51229a4ac695a1038cd2f2.png
# 3.0
#
# respuestas/7081ab4816847c17c866442f1d0251e3.png
# 3.9
#
# respuestas/aa4df829a7123f0fb1665c4f58679f3f.png
# 3.6
#
# respuestas/e8f574cdcd73c1f5716fcfaff704993a.png
# .
# 4
#
# respuestas/db607a47c78d2ce8749e59a57906043b.png
# 4.4
#
# respuestas/b597521adbd59ef25bc651313df6984c.png
# 45
# .
#
# respuestas/d66401797c38bcae56b1089fa47bf34f.png
# 4.2
#
# respuestas/81d4085932b93c802e971f7541f100d3.png
# respuestas/1ab689a4442c2bd95b4c12cfcd7be825.png
# 4
# .
# 86
#
# respuestas/ea6adde3187da314bc4e3ee00bbb094c.png
# 4.0
#
# respuestas/36ed870b59ee09bc61cbcc78f303e79a.png
# respuestas/5957bf600daed15adc9e5d16b2b26758.png
# 1
#
# respuestas/c4666f597ed18f6abb54231fc8107c3a.png
